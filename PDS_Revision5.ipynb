# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryARavichan/PYTHON-FOR-DATA-SCIENCE-BDA-/blob/main/PDS_Revision5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class person:
  def __init__(self):
    self.name='Cindhu'
    self.db=self.Dob()
  def display(self):
    print('Name= ',self.name)
  #creating a inner class
  class Dob:
    def __init__(self):
      self.dd=30
      self.mm=6
      self.yy=1987
    def display(self):
      print('Dob={}/{}/{}'.format(self.dd,self.mm,self.yy))

# %%
#creating person class object
p=person()
p.display()
# Out:
# Name=  Cindhu

# %%
y=person().Dob()
y.display()
# Out:
# Dob=30/6/1987

# %%
#create inner class object
x=p.db
x.display()
# Out:
# Dob=30/6/1987

# %%
class person:
  def __init__(self):
    self.name='Cindhu'
    
  def display(self):
    print('Name= ',self.name)

  #creating a inner class
  class Dob:
    def __init__(self):
      self.dd=30
      self.mm=6
      self.yy=1987
    def display(self):
      print('Dob={}/{}/{}'.format(self.dd,self.mm,self.yy))

# %%
#creating person class object
p=person()
p.display()
# Out:
# Name=  Cindhu

# %%
x=person().Dob() #create inner class object
x.display() #call inner class method
# Out:
# Dob=30/6/1987

# %%
class Teacher:
  def setid(self,id):
    self.id=id
  def getid(self):
    return self.id
  def setname(self,name):
    self.name=name
  def getname(self):
    return self.name
  def setaddress(self,address):
    self.address=address
  def getaddress(self):
    return self.address
  def setsalary(self,salary):
    self.salary=salary
  def getsalary(self):
    return self.salary

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys

# %%
sys.path.insert(0,'/content/drive/My Drive/Python Basics/')

# %%
from teacher import Teacher

# %%
t=Teacher()

# %%
t.setid(10)
t.setname('kala')
t.setaddress('HNO-5, Poes Garden,Teynampet')
t.setsalary(48800)

# %%
#retrieve data from instance and display
print('id=',t.getid())
print('name=',t.getname())
print('address=',t.getaddress())
print('salary=',t.getsalary())
# Out:
# id= 10
# name= kala
# address= HNO-5, Poes Garden,Teynampet
# salary= 48800

# %%
class Student(Teacher):
  def setmarks(self,marks):
    self.marks=marks
  def getmarks(self):
    return self.marks

# %% [markdown]
# Student class is derived from teacher class (Inheritance)

# %%
#create instance
s=Student()
s.setid(115)
s.setname('Ravi')
s.setaddress('HNO-1/265, Gandhi Street,West Mambalam')
s.setmarks(950)

# %%
#retrieve data from instance and display
print('id=',s.getid())
print('name=',s.getname())
print('address=',s.getaddress())
print('salary=',s.getmarks())
# Out:
# id= 115
# name= Ravi
# address= HNO-1/265, Gandhi Street,West Mambalam
# salary= 950

# %% [markdown]
# The original Teacher class is base class or super class. The newly created student class is called sub-class or derived class

# %%
#consider this Duck class contains talk() method
class Duck:
  def talk(self):
    print('Quack, Quack!')
#consider this Human class contains talk() method
class Human:
  def talk(self):
    print('Hello Hi!')

# %%
def call_talk(obj):
  obj.talk()

# %%
#depending on type of object,talk() method is executed
x=Duck()
call_talk(x)
# Out:
# Quack, Quack!

# %%
x=Human()
call_talk(x)
# Out:
# Hello Hi!

# %%
#Reading and displaying images in Python

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow
#cv2.imshow() is disabled in Colab, because it causes Jupyter sessions to crash
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
D=cv2.imread('/content/drive/My Drive/Python Basics/srm.jpg')

# %%
D.shape
# Out:
# (220, 320, 3)

# %%
cv2_imshow(D)
# Out:
# <PIL.Image.Image image mode=RGB size=320x220 at 0x7F8907A86290>

# %%
D[:20,:20,0]=0
D[:20,:20,2]=0

# %%
D[:20,-20:,0]=0
D[:20,-20:,2]=0

# %%
,header=0,parse_dates=[0],index_col=0,squeeze=True

# %%
cv2_imshow(D)
# Out:
# <PIL.Image.Image image mode=RGB size=320x220 at 0x7F89061B24D0>

# %% [markdown]
# Reading a Time-Series Data

# %%
B=pd.read_csv('/content/drive/My Drive/Time Series/daily-minimum-temperatures.csv',header=0,parse_dates=[0],index_col=0,squeeze=True)
B.tail()
#1981-1990 (10 years data of city of melbourne, Australia)
# Out:
# Date
# 1990-12-27    14.0
# 1990-12-28    13.6
# 1990-12-29    13.5
# 1990-12-30    15.7
# 1990-12-31    13.0
# Name: Temp, dtype: float64

# %%
type(B)
# Out:
# pandas.core.series.Series

# %%
plt.rcParams['figure.figsize'] = [15,8]

# %%
B.plot()

# %%
#plot any one year data
B['1981'].plot()

# %%
B['1981-1'].plot()

# %%
B['1981'].describe()
# Out:
# count    365.00000
# mean      11.51726
# std        4.33743
# min        2.10000
# 25%        8.30000
# 50%       11.20000
# 75%       14.40000
# max       25.00000
# Name: Temp, dtype: float64

# %%
B['1990'].describe()
# Out:
# count    365.000000
# mean      11.669589
# std        3.861600
# min        2.100000
# 25%        8.700000
# 50%       11.400000
# 75%       14.600000
# max       22.100000
# Name: Temp, dtype: float64

# %%
B['1981-01':'1981-08'].plot()

# %% [markdown]
# Reading a text file

# %%
file=open('/content/drive/My Drive/DL/sample.txt','rt')
text=file.read()
file.close()

# %%
text
# Out:
# 'Computer vision is not just a way to convert pictures to pixels, and it can’t make sense of a picture just from its pixels. It’s the ability of a machine to take a step back and interpret the big picture that those pixels represent. And that’s much harder than we think it is.\nFor instance, when we see a picture of a model wearing a dress, we automatically identify which part of the body we’re looking at and from which angle. We can figure out lighting conditions. We may even be able to judge the color and texture of the clothes based on shadows, highlights and color temperature.'

# %%
words=text.split()
words
# Out:
# ['Computer',
#  'vision',
#  'is',
#  'not',
#  'just',
#  'a',
#  'way',
#  'to',
#  'convert',
#  'pictures',
#  'to',
#  'pixels,',
#  'and',
#  'it',
#  'can’t',
#  'make',
#  'sense',
#  'of',
#  'a',
#  'picture',
#  'just',
#  'from',
#  'its',
#  'pixels.',
#  'It’s',
#  'the',
#  'ability',
#  'of',
#  'a',
#  'machine',
#  'to',
#  'take',
#  'a',
#  'step',
#  'back',
#  'and',
#  'interpret',
#  'the',
#  'big',
#  'picture',
#  'that',
#  'those',
#  'pixels',
#  'represent.',
#  'And',
#  'that’s',
#  'much',
#  'harder',
#  'than',
#  'we',
#  'think',
#  'it',
#  'is.',
#  'For',
#  'instance,',
#  'when',
#  'we',
#  'see',
#  'a',
#  'picture',
#  'of',
#  'a',
#  'model',
#  'wearing',
#  'a',
#  'dress,',
#  'we',
#  'automatically',
#  'identify',
#  'which',
#  'part',
#  'of',
#  'the',
#  'body',
#  'we’re',
#  'looking',
#  'at',
#  'and',
#  'from',
#  'which',
#  'angle.',
#  'We',
#  'can',
#  'figure',
#  'out',
#  'lighting',
#  'conditions.',
#  'We',
# ...

# %%
len(words)
# Out:
# 108

# %%
'Hello'.lower()
# Out:
# 'hello'

# %%
words_lower=[ w.lower() for w in words]      
words_lower
# Out:
# ['computer',
#  'vision',
#  'is',
#  'not',
#  'just',
#  'a',
#  'way',
#  'to',
#  'convert',
#  'pictures',
#  'to',
#  'pixels,',
#  'and',
#  'it',
#  'can’t',
#  'make',
#  'sense',
#  'of',
#  'a',
#  'picture',
#  'just',
#  'from',
#  'its',
#  'pixels.',
#  'it’s',
#  'the',
#  'ability',
#  'of',
#  'a',
#  'machine',
#  'to',
#  'take',
#  'a',
#  'step',
#  'back',
#  'and',
#  'interpret',
#  'the',
#  'big',
#  'picture',
#  'that',
#  'those',
#  'pixels',
#  'represent.',
#  'and',
#  'that’s',
#  'much',
#  'harder',
#  'than',
#  'we',
#  'think',
#  'it',
#  'is.',
#  'for',
#  'instance,',
#  'when',
#  'we',
#  'see',
#  'a',
#  'picture',
#  'of',
#  'a',
#  'model',
#  'wearing',
#  'a',
#  'dress,',
#  'we',
#  'automatically',
#  'identify',
#  'which',
#  'part',
#  'of',
#  'the',
#  'body',
#  'we’re',
#  'looking',
#  'at',
#  'and',
#  'from',
#  'which',
#  'angle.',
#  'we',
#  'can',
#  'figure',
#  'out',
#  'lighting',
#  'conditions.',
#  'we',
# ...
